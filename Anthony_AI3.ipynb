# %% [markdown]
# # Ujian Akhir Artificial Intelligence

# %% [markdown]
# # Soal 1 : Mempersiapkan Data

# %%
import pandas as pd
df = pd.read_csv('PH2Dataset.csv').drop(columns='Histological Diagnosis')

# %%
df_CN = df[['Image Name','Common Nevus']].dropna()
df_AN = df[['Image Name','Atypical Nevus']].dropna()
df_M = df[['Image Name','Melanoma']].dropna()
#df.head()
df_CN_list = []
df_AN_list = []
df_M_list  = []
for i in df_CN['Image Name']:
    df_CN_list.append(i)
for i in df_AN['Image Name']:
    df_AN_list.append(i)
for i in df_M['Image Name']:
    df_M_list.append(i)

# %% [markdown]
# ## Membagi Original file menjadi beberapa folder

# %% [markdown]
# ### Memanggil path ke setiap image

# %%
new_folder = 'original_dataset'
#!mkdir $new_folder

image_path_CN = []
image_path_AN = []
image_path_M  = []
path = 'PH2Dataset\PH2_Dataset_images'
for filename in os.listdir(path):
    if filename in df_CN_list:
        for fileImages in os.listdir(path+'/'+filename+'/'+filename+"_Dermoscopic_Image"):
            image_path_CN.append(path+'\\'+filename+'\\'+filename+'_Dermoscopic_Image\\'+fileImages)
    elif filename in df_AN_list: 
        for fileImages in os.listdir(path+'/'+filename+'/'+filename+"_Dermoscopic_Image"):
            image_path_AN.append(path+'\\'+filename+'\\'+filename+'_Dermoscopic_Image\\'+fileImages)
    elif filename in df_M_list: 
        for fileImages in os.listdir(path+'/'+filename+'/'+filename+"_Dermoscopic_Image"):
            image_path_M.append(path+'\\'+filename+'\\'+filename+'_Dermoscopic_Image\\'+fileImages)                           
                                 
image_path_CN, image_path_AN, image_path_M
# Out:
# (['PH2Dataset\\PH2_Dataset_images\\IMD003\\IMD003_Dermoscopic_Image\\IMD003.bmp',
#   'PH2Dataset\\PH2_Dataset_images\\IMD009\\IMD009_Dermoscopic_Image\\IMD009.bmp',
#   'PH2Dataset\\PH2_Dataset_images\\IMD010\\IMD010_Dermoscopic_Image\\IMD010.bmp',
#   'PH2Dataset\\PH2_Dataset_images\\IMD016\\IMD016_Dermoscopic_Image\\IMD016.bmp',
#   'PH2Dataset\\PH2_Dataset_images\\IMD017\\IMD017_Dermoscopic_Image\\IMD017.bmp',
#   'PH2Dataset\\PH2_Dataset_images\\IMD020\\IMD020_Dermoscopic_Image\\IMD020.bmp',
#   'PH2Dataset\\PH2_Dataset_images\\IMD022\\IMD022_Dermoscopic_Image\\IMD022.bmp',
#   'PH2Dataset\\PH2_Dataset_images\\IMD024\\IMD024_Dermoscopic_Image\\IMD024.bmp',
#   'PH2Dataset\\PH2_Dataset_images\\IMD025\\IMD025_Dermoscopic_Image\\IMD025.bmp',
#   'PH2Dataset\\PH2_Dataset_images\\IMD035\\IMD035_Dermoscopic_Image\\IMD035.bmp',
#   'PH2Dataset\\PH2_Dataset_images\\IMD038\\IMD038_Dermoscopic_Image\\IMD038.bmp',
# ...

# %% [markdown]
# ### Copy ke directory

# %%
# !mkdir $new_folder\Atypical_Nevus
# !mkdir $new_folder\Common_Nevus
# !mkdir $new_folder\Melanoma

for i in image_path_CN:
    # !copy $i $new_folder\\Common_Nevus
for i in image_path_AN:
    # !copy $i $new_folder\\Atypical_Nevus
for i in image_path_M:
    # !copy $i $new_folder\\Melanoma
# Out:
# A subdirectory or file original_dataset\Atypical_Nevus already exists.
# A subdirectory or file original_dataset\Common_Nevus already exists.
# ppmPH2HairRemove\IMD170.ppm\inpainted.ppm
# A subdirectory or file original_dataset\Melanoma already exists.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
# ...

# %% [markdown]
# ## Inpainted Data 3 Kelas

# %%
new_folder = 'inpainted_dataset'
#!mkdir $new_folder

#!mkdir $new_folder\Atypical_Nevus
#!mkdir $new_folder\Common_Nevus
#!mkdir $new_folder\Melanoma

path = 'ppmPH2HairRemove'
for filename in os.listdir(path):
    if filename.split(".",1)[0] in df_CN_list:
        image_path = (path+'\\'+filename+'\\inpainted.ppm')
        # !copy $image_path $new_folder\\Common_Nevus\\$filename
    elif filename.split(".",1)[0] in df_AN_list: 
        image_path = (path+'\\'+filename+'\\inpainted.ppm')
        # !copy $image_path $new_folder\\Atypical_Nevus\\$filename
    elif filename.split(".",1)[0] in df_M_list: 
        image_path  = (path+'\\'+filename+'\\inpainted.ppm')
        # !copy $image_path $new_folder\\Melanoma\\$filename
# Out:
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
# ...

# %% [markdown]
# ## Original Inpainted Data 3 Kelas

# %%
new_folder = 'original_inpainted_dataset'
# !mkdir $new_folder

# !mkdir $new_folder\Atypical_Nevus\inpainted
# !mkdir $new_folder\Atypical_Nevus\original
# !mkdir $new_folder\Common_Nevus\inpainted
# !mkdir $new_folder\Common_Nevus\original
# !mkdir $new_folder\Melanoma\inpainted
# !mkdir $new_folder\Melanoma\original

path = 'ppmPH2HairRemove'
for filename in os.listdir(path):
    if filename.split(".",1)[0] in df_CN_list:
        image_path = (path+'\\'+filename+'\\inpainted.ppm')
        # !copy $image_path $new_folder\\Common_Nevus\\inpainted\\$filename
        image_path = (path+'\\'+filename+'\\original.ppm')
        # !copy $image_path $new_folder\\Common_Nevus\\original\\$filename
    elif filename.split(".",1)[0] in df_AN_list: 
        image_path = (path+'\\'+filename+'\\inpainted.ppm')
        # !copy $image_path $new_folder\\Atypical_Nevus\\inpainted\\$filename
        image_path = (path+'\\'+filename+'\\original.ppm')
        # !copy $image_path $new_folder\\Atypical_Nevus\\original\\$filename
    elif filename.split(".",1)[0] in df_M_list: 
        image_path  = (path+'\\'+filename+'\\inpainted.ppm')
        # !copy $image_path $new_folder\\Melanoma\\inpainted\\$filename
        image_path = (path+'\\'+filename+'\\original.ppm')
        # !copy $image_path $new_folder\\Melanoma\\original\\$filename
# Out:
# A subdirectory or file original_inpainted_dataset already exists.
# A subdirectory or file original_inpainted_dataset\Atypical_Nevus\inpainted already exists.
# A subdirectory or file original_inpainted_dataset\Atypical_Nevus\original already exists.
# A subdirectory or file original_inpainted_dataset\Common_Nevus\inpainted already exists.
# A subdirectory or file original_inpainted_dataset\Common_Nevus\original already exists.
# A subdirectory or file original_inpainted_dataset\Melanoma\inpainted already exists.
# A subdirectory or file original_inpainted_dataset\Melanoma\original already exists.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
# ...

# %% [markdown]
# ## Original Data 2 Kelas

# %%
new_folder = 'original_2kelas_dataset'
# !mkdir $new_folder

# !mkdir $new_folder\Melanoma
# !mkdir $new_folder\NonMelanoma


path = 'PH2Dataset\PH2_Dataset_images'
for filename in os.listdir(path):
    if filename not in df_M_list:
        for fileImages in os.listdir(path+'/'+filename+'/'+filename+"_Dermoscopic_Image"):
            image_path = (path+'\\'+filename+'\\'+filename+'_Dermoscopic_Image\\'+fileImages)
            # !copy $image_path $new_folder\\NonMelanoma
    elif filename in df_M_list: 
        for fileImages in os.listdir(path+'/'+filename+'/'+filename+"_Dermoscopic_Image"):
            image_path = (path+'\\'+filename+'\\'+filename+'_Dermoscopic_Image\\'+fileImages) 
            # !copy $image_path $new_folder\\Melanoma
# Out:
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
# ...

# %% [markdown]
# ## Inpainted Data 2 Kelas

# %%
new_folder = 'inpainted_2kelas_dataset'
# !mkdir $new_folder

# !mkdir $new_folder\Melanoma
# !mkdir $new_folder\NonMelanoma


path = 'ppmPH2HairRemove'
for filename in os.listdir(path):
    if filename.split(".",1)[0] in df_M_list:
        image_path = (path+'\\'+filename+'\\inpainted.ppm')
        # !copy $image_path $new_folder\\Melanoma\\$filename
    if filename.split(".",1)[0] not in df_M_list:
        image_path = (path+'\\'+filename+'\\inpainted.ppm')
        # !copy $image_path $new_folder\\NonMelanoma\\$filename
# Out:
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
# ...

# %% [markdown]
# ## Original Inpainted 2 Kelas

# %%
new_folder = 'original_inpainted_2kelas_dataset'
#!mkdir $new_folder

#!mkdir $new_folder\Melanoma\original
#!mkdir $new_folder\Melanoma\inpainted
#!mkdir $new_folder\NonMelanoma\original
#!mkdir $new_folder\NonMelanoma\inpainted


path = 'ppmPH2HairRemove'
for filename in os.listdir(path):
    if filename.split(".",1)[0] in df_M_list:
        image_path = (path+'\\'+filename+'\\inpainted.ppm')
        # !copy $image_path $new_folder\\Melanoma\\inpainted\\$filename
        image_path = (path+'\\'+filename+'\\original.ppm')
        # !copy $image_path $new_folder\\Melanoma\\original\\$filename
    if filename.split(".",1)[0] not in df_M_list:
        image_path = (path+'\\'+filename+'\\inpainted.ppm')
        # !copy $image_path $new_folder\\NonMelanoma\\inpainted\\$filename
        image_path = (path+'\\'+filename+'\\original.ppm')
        # !copy $image_path $new_folder\\NonMelanoma\\original\\$filename
# Out:
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
#         1 file(s) copied.
# ...

# %% [markdown]
# # Membuat file train, val, dan test

# %%
import numpy as np
import os
from PIL import Image
from imutils import paths

#imagePaths = paths.list_images("original_2kelas_dataset")
imagePaths = paths.list_files("original_inpainted_2kelas_dataset",validExts='.ppm')

data = []
labels = []
Cancers = {'Common_Nevus':1,'Atypical_Nevus':2,'Melanoma':3,'NonMelanoma':4}


for imagePath in imagePaths:
    pillow = Image.open(imagePath)
    pillow = pillow.resize((128,128))
    image = np.array(pillow)
    data.append(image)
    label = imagePath.split(os.path.sep)[-3]
    labels.append(Cancers[label])
    pillow.close()

data
# Out:
# [array([[[64, 52, 45],
#          [65, 53, 46],
#          [51, 50, 43],
#          ...,
#          [54, 45, 42],
#          [62, 57, 50],
#          [64, 52, 51]],
#
#         [[65, 55, 44],
#          [58, 44, 35],
#          [69, 51, 52],
#          ...,
#          [60, 47, 44],
#          [62, 47, 50],
#          [63, 54, 53]],
#
#         [[66, 48, 51],
#          [61, 47, 43],
#          [66, 57, 53],
#          ...,
#          [63, 55, 51],
#          [60, 51, 56],
#          [62, 52, 57]],
#
#         ...,
#
#         [[49, 36, 36],
#          [48, 42, 30],
#          [49, 40, 35],
#          ...,
#          [54, 41, 33],
#          [55, 38, 33],
#          [57, 39, 36]],
#
#         [[51, 38, 38],
#          [53, 41, 39],
#          [53, 39, 42],
#          ...,
#          [59, 42, 40],
#          [59, 44, 32],
#          [56, 42, 35]],
#
#         [[55, 39, 32],
#          [50, 43, 33],
#          [51, 45, 34],
#          ...,
#          [53, 36, 35],
# ...

# %% [markdown]
# ### Membagi file menjadi train, val, dan test

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,Y_train, Y_test = train_test_split(data ,labels, test_size=0.2, random_state=1)
X_val, X_test, Y_val, Y_test = train_test_split(X_test, Y_test, test_size=0.5, random_state=1)
print(len(X_train),len(X_test),len(X_val))
# Out:
# 576 72 72

# %%
X_train = np.array(X_train)
X_test = np.array(X_test)
X_val = np.array(X_val)
X_train.shape
# Out:
# (576, 128, 128, 3)

# %% [markdown]
# # Soal 2 : Klasifikasi Gambar

# %% [markdown]
# ## Mempersiapkan CNN Model
# Sumber : https://androidkt.com/feeding-your-own-data-set-into-the-cnn-model-in-tensorflow/

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="-1"   
import tensorflow as tf
gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=0.5)
sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True, log_device_placement=True))
"""Model function for CNN."""

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(filters=48, kernel_size=(3, 3), activation=tf.nn.relu, input_shape=( 128, 128, 3), padding='same'),
    tf.keras.layers.MaxPooling2D(pool_size=(3, 3)),
    tf.keras.layers.Conv2D(filters=128, kernel_size=(3, 3), activation=tf.nn.relu, padding='same'),
    tf.keras.layers.MaxPooling2D(pool_size=(3, 3)),
    tf.keras.layers.Conv2D(filters=192, kernel_size=(3, 3), activation=tf.nn.relu, padding='same'),
    tf.keras.layers.Conv2D(filters=192, kernel_size=(3, 3), activation=tf.nn.relu, padding='same'),
    tf.keras.layers.Conv2D(filters=128, kernel_size=(3, 3), activation=tf.nn.relu, padding='same'),
    tf.keras.layers.MaxPooling2D(pool_size=(3, 3)),
])

model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_35 (Conv2D)           (None, 128, 128, 48)      1344
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 42, 42, 48)        0
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 42, 42, 128)       55424
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 14, 14, 192)       221376
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 14, 14, 192)       331968
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 14, 14, 128)       221312
# ...

# %%
model.add(tf.keras.layers.Flatten())  # Flatten "squeezes" a 3-D volume down into a single vector.
model.add(tf.keras.layers.Dense(1024, activation=tf.nn.relu))
model.add(tf.keras.layers.Dropout(rate=0.5))
model.add(tf.keras.layers.Dense(1024, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(10, activation=tf.nn.softmax))
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_35 (Conv2D)           (None, 128, 128, 48)      1344
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 42, 42, 48)        0
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 42, 42, 128)       55424
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 14, 14, 192)       221376
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 14, 14, 192)       331968
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 14, 14, 128)       221312
# ...

# %%
model.compile(optimizer=tf.train.AdamOptimizer(),
              loss=tf.keras.losses.sparse_categorical_crossentropy,
              metrics=['accuracy'])

# %%
model.fit(X_train, Y_train, epochs=30, batch_size=32,validation_data=(X_val,Y_val))
# Out:
# Train on 576 samples, validate on 72 samples
# Epoch 1/30
# 576/576 [==============================] - 9s 16ms/sample - loss: 9.2006 - acc: 0.4965 - val_loss: 0.7010 - val_acc: 0.5139
# Epoch 2/30
# 576/576 [==============================] - 9s 16ms/sample - loss: 0.7475 - acc: 0.5434 - val_loss: 0.7031 - val_acc: 0.4722
# Epoch 3/30
# 576/576 [==============================] - 9s 16ms/sample - loss: 0.7322 - acc: 0.5069 - val_loss: 0.7016 - val_acc: 0.4583
# Epoch 4/30
# 576/576 [==============================] - 9s 16ms/sample - loss: 0.7149 - acc: 0.5208 - val_loss: 0.7038 - val_acc: 0.5417
# Epoch 5/30
# 576/576 [==============================] - 9s 16ms/sample - loss: 0.7153 - acc: 0.5330 - val_loss: 0.7275 - val_acc: 0.5417
# Epoch 6/30
# 576/576 [==============================] - 9s 16ms/sample - loss: 0.7078 - acc: 0.5608 - val_loss: 0.6931 - val_acc: 0.5417
# Epoch 7/30
# ...

# %%
metric_values = model.evaluate(x=X_test, y=Y_test)

print('Final TEST performance')
for metric_value, metric_name in zip(metric_values, model.metrics_names):
  print('{}: {}'.format(metric_name, metric_value))
# Out:
# 72/72 [==============================] - 0s 5ms/sample - loss: 0.7046 - acc: 0.4444
# Final TEST performance
# loss: 0.7045895788404677
# acc: 0.4444444477558136

# %% [markdown]
# ## Mencoba menggunakan file yang dipakai dalam latihan klasifikasi 3Scenes

# %%
# %run -i classify_image.py -d original_2kelas_dataset -m svm
# Out:
# featureType : stat 1
# [INFO] extracting image features...
# [INFO] loading data...
# [INFO] using 'svm' model
# [INFO] evaluating...
#               precision    recall  f1-score   support
#
#     Melanoma       0.88      0.88      0.88         8
#  NonMelanoma       0.97      0.97      0.97        32
#
#     accuracy                           0.95        40
#    macro avg       0.92      0.92      0.92        40
# weighted avg       0.95      0.95      0.95        40

# %%
# %run -i classify_image_for_ppm.py -d original_inpainted_2kelas_dataset -m random_forest
# Out:
# featureType : stat 1
# [INFO] extracting image features...
# [INFO] loading data...
# [INFO] using 'random_forest' model
# [INFO] evaluating...
#               precision    recall  f1-score   support
#
#     Melanoma       0.34      0.26      0.29        94
#  NonMelanoma       0.05      0.08      0.06        50
#
#     accuracy                           0.19       144
#    macro avg       0.20      0.17      0.18       144
# weighted avg       0.24      0.19      0.21       144
